# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install tensorboardX
# Out:
# Collecting tensorboardX
#   Downloading tensorboardX-2.6.1-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX) (23.1)
# Collecting protobuf>=4.22.3 (from tensorboardX)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: protobuf, tensorboardX
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed protobuf-4.23.4 tensorboardX-2.6.1

# %%
# %cd /content/drive/MyDrive/github/LightGCN_PyTorch/code
# Out:
# /content/drive/MyDrive/github/LightGCN_PyTorch/code

# %%
# %run main.py --decay=1e-4 --lr=0.001 --layer=3 --seed=2020 --dataset="yelp2018" --topks="[20]" --recdim=64 --epochs=500 --model='mf'
# Out:
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/yelp2018]
# 1237259 interactions for training
# 324147 interactions for testing
# yelp2018 Sparsity : 0.0012958757851778647
# yelp2018 is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 0,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 1
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# using Normal distribution N(0,1) initialization for PureMF
# load and save to /content/drive/MyDrive/github/LightGCN_PyTorch/code/checkpoints/mf-yelp2018-64.pth.tar
# [TEST]
# {'precision': array([0.00046261]), 'recall': array([0.00093365]), 'ndcg': array([0.00069569])}
# EPOCH[1/500] loss4.417-|Sample:20.51|
# EPOCH[2/500] loss4.133-|Sample:19.19|
# EPOCH[3/500] loss3.849-|Sample:20.72|
# EPOCH[4/500] loss3.587-|Sample:19.14|
# EPOCH[5/500] loss3.357-|Sample:19.57|
# EPOCH[6/500] loss3.122-|Sample:18.86|
# EPOCH[7/500] loss2.933-|Sample:20.02|
# EPOCH[8/500] loss2.753-|Sample:20.14|
# EPOCH[9/500] loss2.570-|Sample:18.47|
# EPOCH[10/500] loss2.411-|Sample:20.54|
# [TEST]
# {'precision': array([0.00040419]), 'recall': array([0.00078917]), 'ndcg': array([0.00063329])}
# EPOCH[11/500] loss2.259-|Sample:20.54|
# EPOCH[12/500] loss2.124-|Sample:19.15|
# EPOCH[13/500] loss1.993-|Sample:20.48|
# EPOCH[14/500] loss1.877-|Sample:18.58|
# EPOCH[15/500] loss1.765-|Sample:20.00|
# EPOCH[16/500] loss1.661-|Sample:18.44|
# EPOCH[17/500] loss1.559-|Sample:19.20|
# EPOCH[18/500] loss1.468-|Sample:19.83|
# EPOCH[19/500] loss1.380-|Sample:18.32|
# EPOCH[20/500] loss1.299-|Sample:19.70|
# [TEST]
# {'precision': array([0.00049419]), 'recall': array([0.00104416]), 'ndcg': array([0.00075064])}
# EPOCH[21/500] loss1.226-|Sample:19.84|
# EPOCH[22/500] loss1.152-|Sample:18.61|
# EPOCH[23/500] loss1.086-|Sample:19.90|
# EPOCH[24/500] loss1.022-|Sample:18.83|
# EPOCH[25/500] loss0.963-|Sample:20.04|
# EPOCH[26/500] loss0.901-|Sample:18.31|
# EPOCH[27/500] loss0.847-|Sample:19.84|
# EPOCH[28/500] loss0.794-|Sample:18.40|
# EPOCH[29/500] loss0.746-|Sample:19.80|
# EPOCH[30/500] loss0.700-|Sample:18.12|
# [TEST]
# {'precision': array([0.00098206]), 'recall': array([0.00222329]), 'ndcg': array([0.00158718])}
# EPOCH[31/500] loss0.653-|Sample:18.53|
# EPOCH[32/500] loss0.615-|Sample:19.61|
# EPOCH[33/500] loss0.575-|Sample:18.12|
# EPOCH[34/500] loss0.535-|Sample:20.13|
# EPOCH[35/500] loss0.501-|Sample:18.04|
# EPOCH[36/500] loss0.469-|Sample:20.04|
# EPOCH[37/500] loss0.440-|Sample:18.13|
# EPOCH[38/500] loss0.407-|Sample:19.76|
# EPOCH[39/500] loss0.381-|Sample:18.33|
# EPOCH[40/500] loss0.355-|Sample:19.63|
# [TEST]
# {'precision': array([0.00274094]), 'recall': array([0.00569862]), 'ndcg': array([0.0043493])}
# EPOCH[41/500] loss0.332-|Sample:18.84|
# EPOCH[42/500] loss0.309-|Sample:18.46|
# EPOCH[43/500] loss0.291-|Sample:19.28|
# EPOCH[44/500] loss0.271-|Sample:18.46|
# EPOCH[45/500] loss0.255-|Sample:18.98|
# EPOCH[46/500] loss0.239-|Sample:18.96|
# EPOCH[47/500] loss0.224-|Sample:18.86|
# EPOCH[48/500] loss0.211-|Sample:19.73|
# EPOCH[49/500] loss0.196-|Sample:18.38|
# EPOCH[50/500] loss0.185-|Sample:19.37|
# [TEST]
# {'precision': array([0.00506979]), 'recall': array([0.00959131]), 'ndcg': array([0.00752472])}
# EPOCH[51/500] loss0.175-|Sample:19.75|
# EPOCH[52/500] loss0.165-|Sample:18.67|
# EPOCH[53/500] loss0.156-|Sample:19.92|
# EPOCH[54/500] loss0.147-|Sample:18.35|
# EPOCH[55/500] loss0.140-|Sample:20.27|
# EPOCH[56/500] loss0.131-|Sample:18.12|
# EPOCH[57/500] loss0.126-|Sample:19.88|
# EPOCH[58/500] loss0.120-|Sample:18.40|
# EPOCH[59/500] loss0.115-|Sample:20.43|
# EPOCH[60/500] loss0.109-|Sample:17.99|
# [TEST]
# {'precision': array([0.00661235]), 'recall': array([0.01199274]), 'ndcg': array([0.00981579])}
# EPOCH[61/500] loss0.104-|Sample:18.49|
# EPOCH[62/500] loss0.100-|Sample:19.60|
# EPOCH[63/500] loss0.096-|Sample:18.43|
# EPOCH[64/500] loss0.093-|Sample:19.26|
# EPOCH[65/500] loss0.089-|Sample:18.21|
# EPOCH[66/500] loss0.085-|Sample:19.83|
# EPOCH[67/500] loss0.082-|Sample:18.51|
# EPOCH[68/500] loss0.080-|Sample:19.21|
# EPOCH[69/500] loss0.077-|Sample:18.35|
# EPOCH[70/500] loss0.074-|Sample:20.09|
# [TEST]
# {'precision': array([0.00758179]), 'recall': array([0.01365966]), 'ndcg': array([0.01120587])}
# EPOCH[71/500] loss0.072-|Sample:18.40|
# EPOCH[72/500] loss0.070-|Sample:19.26|
# EPOCH[73/500] loss0.068-|Sample:18.57|
# EPOCH[74/500] loss0.066-|Sample:19.47|
# EPOCH[75/500] loss0.064-|Sample:18.29|
# EPOCH[76/500] loss0.061-|Sample:19.49|
# EPOCH[77/500] loss0.061-|Sample:18.55|
# EPOCH[78/500] loss0.060-|Sample:19.95|
# EPOCH[79/500] loss0.058-|Sample:18.87|
# EPOCH[80/500] loss0.057-|Sample:19.97|
# [TEST]
# {'precision': array([0.00812018]), 'recall': array([0.01481247]), 'ndcg': array([0.01204624])}
# EPOCH[81/500] loss0.055-|Sample:19.62|
# EPOCH[82/500] loss0.054-|Sample:18.21|
# EPOCH[83/500] loss0.053-|Sample:19.46|
# EPOCH[84/500] loss0.052-|Sample:18.33|
# EPOCH[85/500] loss0.050-|Sample:19.42|
# EPOCH[86/500] loss0.050-|Sample:17.72|
# EPOCH[87/500] loss0.049-|Sample:19.71|
# EPOCH[88/500] loss0.048-|Sample:17.94|
# EPOCH[89/500] loss0.047-|Sample:19.48|
# EPOCH[90/500] loss0.046-|Sample:18.09|
# [TEST]
# {'precision': array([0.00866174]), 'recall': array([0.01591796]), 'ndcg': array([0.0129837])}
# EPOCH[91/500] loss0.045-|Sample:17.73|
# EPOCH[92/500] loss0.044-|Sample:19.59|
# EPOCH[93/500] loss0.044-|Sample:18.13|
# EPOCH[94/500] loss0.043-|Sample:19.35|
# EPOCH[95/500] loss0.042-|Sample:17.95|
# EPOCH[96/500] loss0.042-|Sample:19.38|
# EPOCH[97/500] loss0.041-|Sample:17.71|
# EPOCH[98/500] loss0.041-|Sample:19.69|
# EPOCH[99/500] loss0.040-|Sample:17.94|
# EPOCH[100/500] loss0.040-|Sample:19.67|
# [TEST]
# {'precision': array([0.00901541]), 'recall': array([0.01665986]), 'ndcg': array([0.01357126])}
# EPOCH[101/500] loss0.039-|Sample:19.37|
# EPOCH[102/500] loss0.039-|Sample:17.68|
# EPOCH[103/500] loss0.039-|Sample:19.48|
# EPOCH[104/500] loss0.038-|Sample:18.23|
# EPOCH[105/500] loss0.038-|Sample:19.51|
# EPOCH[106/500] loss0.037-|Sample:17.91|
# EPOCH[107/500] loss0.036-|Sample:19.29|
# EPOCH[108/500] loss0.036-|Sample:17.98|
# EPOCH[109/500] loss0.036-|Sample:19.48|
# EPOCH[110/500] loss0.035-|Sample:17.74|
# [TEST]
# {'precision': array([0.00920014]), 'recall': array([0.01717442]), 'ndcg': array([0.01378042])}
# EPOCH[111/500] loss0.034-|Sample:18.27|
# EPOCH[112/500] loss0.035-|Sample:19.06|
# EPOCH[113/500] loss0.035-|Sample:17.76|
# EPOCH[114/500] loss0.034-|Sample:19.33|
# EPOCH[115/500] loss0.034-|Sample:17.71|
# EPOCH[116/500] loss0.034-|Sample:18.71|
# EPOCH[117/500] loss0.034-|Sample:18.00|
# EPOCH[118/500] loss0.033-|Sample:17.93|
# EPOCH[119/500] loss0.033-|Sample:18.77|
# EPOCH[120/500] loss0.032-|Sample:17.82|
# [TEST]
# {'precision': array([0.00943381]), 'recall': array([0.01776652]), 'ndcg': array([0.01425866])}
# EPOCH[121/500] loss0.032-|Sample:18.06|
# EPOCH[122/500] loss0.032-|Sample:18.81|
# EPOCH[123/500] loss0.032-|Sample:18.07|
# EPOCH[124/500] loss0.032-|Sample:19.19|
# EPOCH[125/500] loss0.031-|Sample:17.49|
# EPOCH[126/500] loss0.031-|Sample:19.37|
# EPOCH[127/500] loss0.030-|Sample:17.43|
# EPOCH[128/500] loss0.030-|Sample:19.42|
# EPOCH[129/500] loss0.030-|Sample:17.36|
# EPOCH[130/500] loss0.030-|Sample:19.29|
# [TEST]
# {'precision': array([0.00970538]), 'recall': array([0.01852007]), 'ndcg': array([0.01475733])}
# EPOCH[131/500] loss0.030-|Sample:19.33|
# EPOCH[132/500] loss0.029-|Sample:17.84|
# EPOCH[133/500] loss0.029-|Sample:18.76|
# EPOCH[134/500] loss0.029-|Sample:17.64|
# EPOCH[135/500] loss0.028-|Sample:18.77|
# EPOCH[136/500] loss0.028-|Sample:17.84|
# EPOCH[137/500] loss0.028-|Sample:17.59|
# EPOCH[138/500] loss0.028-|Sample:18.71|
# EPOCH[139/500] loss0.028-|Sample:18.23|
# EPOCH[140/500] loss0.027-|Sample:18.96|
# [TEST]
# {'precision': array([0.00991379]), 'recall': array([0.01888087]), 'ndcg': array([0.01514809])}
# EPOCH[141/500] loss0.027-|Sample:18.95|
# EPOCH[142/500] loss0.027-|Sample:17.47|
# EPOCH[143/500] loss0.027-|Sample:19.59|
# EPOCH[144/500] loss0.027-|Sample:17.41|
# EPOCH[145/500] loss0.027-|Sample:19.14|
# EPOCH[146/500] loss0.026-|Sample:17.82|
# EPOCH[147/500] loss0.027-|Sample:19.65|
# EPOCH[148/500] loss0.026-|Sample:17.35|
# EPOCH[149/500] loss0.026-|Sample:19.43|
# EPOCH[150/500] loss0.026-|Sample:18.04|
# [TEST]
# {'precision': array([0.010078]), 'recall': array([0.01940719]), 'ndcg': array([0.01545973])}
# EPOCH[151/500] loss0.026-|Sample:17.63|
# EPOCH[152/500] loss0.026-|Sample:19.38|
# EPOCH[153/500] loss0.025-|Sample:17.73|
# EPOCH[154/500] loss0.025-|Sample:19.27|
# EPOCH[155/500] loss0.025-|Sample:17.78|
# EPOCH[156/500] loss0.025-|Sample:18.61|
# EPOCH[157/500] loss0.025-|Sample:17.80|
# EPOCH[158/500] loss0.025-|Sample:18.33|
# EPOCH[159/500] loss0.025-|Sample:18.71|
# EPOCH[160/500] loss0.024-|Sample:17.62|
# [TEST]
# {'precision': array([0.01025799]), 'recall': array([0.01993754]), 'ndcg': array([0.01582167])}
# EPOCH[161/500] loss0.024-|Sample:17.68|
# EPOCH[162/500] loss0.024-|Sample:19.17|
# EPOCH[163/500] loss0.024-|Sample:17.80|
# EPOCH[164/500] loss0.024-|Sample:19.21|
# EPOCH[165/500] loss0.024-|Sample:17.76|
# EPOCH[166/500] loss0.024-|Sample:19.39|
# EPOCH[167/500] loss0.023-|Sample:17.84|
# EPOCH[168/500] loss0.024-|Sample:19.45|
# EPOCH[169/500] loss0.023-|Sample:18.16|
# EPOCH[170/500] loss0.023-|Sample:19.18|
# [TEST]
# {'precision': array([0.01074113]), 'recall': array([0.02106198]), 'ndcg': array([0.01684845])}
# EPOCH[171/500] loss0.023-|Sample:19.27|
# EPOCH[172/500] loss0.023-|Sample:18.08|
# EPOCH[173/500] loss0.023-|Sample:19.71|
# EPOCH[174/500] loss0.023-|Sample:17.69|
# EPOCH[175/500] loss0.023-|Sample:19.53|
# EPOCH[176/500] loss0.022-|Sample:18.16|
# EPOCH[177/500] loss0.022-|Sample:19.52|
# EPOCH[178/500] loss0.022-|Sample:18.28|
# EPOCH[179/500] loss0.022-|Sample:19.61|
# EPOCH[180/500] loss0.022-|Sample:17.69|
# [TEST]
# {'precision': array([0.01088165]), 'recall': array([0.0214506]), 'ndcg': array([0.01690104])}
# EPOCH[181/500] loss0.022-|Sample:17.72|
# EPOCH[182/500] loss0.022-|Sample:19.55|
# EPOCH[183/500] loss0.022-|Sample:18.04|
# EPOCH[184/500] loss0.021-|Sample:19.39|
# EPOCH[185/500] loss0.022-|Sample:18.10|
# EPOCH[186/500] loss0.021-|Sample:19.32|
# EPOCH[187/500] loss0.021-|Sample:17.89|
# EPOCH[188/500] loss0.022-|Sample:19.69|
# EPOCH[189/500] loss0.021-|Sample:17.65|
# EPOCH[190/500] loss0.021-|Sample:19.74|
# [TEST]
# {'precision': array([0.01108216]), 'recall': array([0.02198164]), 'ndcg': array([0.01753166])}
# EPOCH[191/500] loss0.021-|Sample:19.13|
# EPOCH[192/500] loss0.021-|Sample:17.91|
# EPOCH[193/500] loss0.021-|Sample:19.49|
# EPOCH[194/500] loss0.021-|Sample:18.05|
# EPOCH[195/500] loss0.021-|Sample:19.35|
# EPOCH[196/500] loss0.021-|Sample:18.07|
# EPOCH[197/500] loss0.021-|Sample:19.49|
# EPOCH[198/500] loss0.021-|Sample:17.58|
# EPOCH[199/500] loss0.020-|Sample:19.67|
# EPOCH[200/500] loss0.020-|Sample:17.69|
# [TEST]
# {'precision': array([0.01127321]), 'recall': array([0.02248707]), 'ndcg': array([0.01783125])}
# EPOCH[201/500] loss0.020-|Sample:18.05|
# EPOCH[202/500] loss0.020-|Sample:19.43|
# EPOCH[203/500] loss0.020-|Sample:17.95|
# EPOCH[204/500] loss0.020-|Sample:19.40|
# EPOCH[205/500] loss0.020-|Sample:17.87|
# EPOCH[206/500] loss0.020-|Sample:19.70|
# EPOCH[207/500] loss0.020-|Sample:17.81|
# EPOCH[208/500] loss0.020-|Sample:19.58|
# EPOCH[209/500] loss0.020-|Sample:17.89|
# EPOCH[210/500] loss0.020-|Sample:19.39|
# [TEST]
# {'precision': array([0.01147689]), 'recall': array([0.02301659]), 'ndcg': array([0.01830142])}
# EPOCH[211/500] loss0.020-|Sample:19.52|
# EPOCH[212/500] loss0.019-|Sample:18.09|
# EPOCH[213/500] loss0.019-|Sample:19.66|
# EPOCH[214/500] loss0.019-|Sample:17.90|
# EPOCH[215/500] loss0.019-|Sample:19.54|
# EPOCH[216/500] loss0.019-|Sample:17.88|
# EPOCH[217/500] loss0.019-|Sample:19.73|
# EPOCH[218/500] loss0.019-|Sample:17.88|
# EPOCH[219/500] loss0.019-|Sample:19.56|
# EPOCH[220/500] loss0.019-|Sample:18.02|
# [TEST]
# {'precision': array([0.01174687]), 'recall': array([0.02355844]), 'ndcg': array([0.01871815])}
# EPOCH[221/500] loss0.019-|Sample:17.95|
# EPOCH[222/500] loss0.019-|Sample:19.54|
# EPOCH[223/500] loss0.018-|Sample:18.24|
# EPOCH[224/500] loss0.019-|Sample:19.63|
# EPOCH[225/500] loss0.018-|Sample:18.00|
# EPOCH[226/500] loss0.018-|Sample:19.37|
# EPOCH[227/500] loss0.018-|Sample:18.27|
# EPOCH[228/500] loss0.018-|Sample:19.50|
# EPOCH[229/500] loss0.018-|Sample:17.82|
# EPOCH[230/500] loss0.018-|Sample:19.57|
# [TEST]
# {'precision': array([0.01199949]), 'recall': array([0.02420105]), 'ndcg': array([0.01926358])}
# EPOCH[231/500] loss0.018-|Sample:19.43|
# EPOCH[232/500] loss0.018-|Sample:17.98|
# EPOCH[233/500] loss0.018-|Sample:19.39|
# EPOCH[234/500] loss0.018-|Sample:17.74|
# EPOCH[235/500] loss0.018-|Sample:19.83|
# EPOCH[236/500] loss0.018-|Sample:18.34|
# EPOCH[237/500] loss0.018-|Sample:19.35|
# EPOCH[238/500] loss0.018-|Sample:17.61|
# EPOCH[239/500] loss0.018-|Sample:19.79|
# EPOCH[240/500] loss0.017-|Sample:17.83|
# [TEST]
# {'precision': array([0.01209265]), 'recall': array([0.02448875]), 'ndcg': array([0.01947512])}
# EPOCH[241/500] loss0.017-|Sample:18.23|
# EPOCH[242/500] loss0.017-|Sample:19.84|
# EPOCH[243/500] loss0.018-|Sample:17.74|
# EPOCH[244/500] loss0.018-|Sample:19.53|
# EPOCH[245/500] loss0.017-|Sample:17.96|
# EPOCH[246/500] loss0.017-|Sample:19.75|
# EPOCH[247/500] loss0.017-|Sample:18.55|
# EPOCH[248/500] loss0.017-|Sample:21.09|
# EPOCH[249/500] loss0.017-|Sample:19.39|
# EPOCH[250/500] loss0.017-|Sample:20.73|
# [TEST]
# {'precision': array([0.01250947]), 'recall': array([0.02548417]), 'ndcg': array([0.0204376])}
# EPOCH[251/500] loss0.017-|Sample:20.06|
# EPOCH[252/500] loss0.017-|Sample:21.62|
# EPOCH[253/500] loss0.017-|Sample:21.25|
# EPOCH[254/500] loss0.017-|Sample:19.57|
# EPOCH[255/500] loss0.017-|Sample:20.70|
# EPOCH[256/500] loss0.017-|Sample:18.92|
# EPOCH[257/500] loss0.017-|Sample:20.38|
# EPOCH[258/500] loss0.017-|Sample:18.71|
# EPOCH[259/500] loss0.016-|Sample:20.96|
# EPOCH[260/500] loss0.017-|Sample:20.35|
# [TEST]
# {'precision': array([0.01261526]), 'recall': array([0.02591291]), 'ndcg': array([0.0206651])}
# EPOCH[261/500] loss0.016-|Sample:21.83|
# EPOCH[262/500] loss0.017-|Sample:19.75|
# EPOCH[263/500] loss0.016-|Sample:21.30|
# EPOCH[264/500] loss0.016-|Sample:19.94|
# EPOCH[265/500] loss0.016-|Sample:21.25|
# EPOCH[266/500] loss0.016-|Sample:22.17|
# EPOCH[267/500] loss0.016-|Sample:20.07|
# EPOCH[268/500] loss0.016-|Sample:21.64|
# EPOCH[269/500] loss0.016-|Sample:22.05|
# EPOCH[270/500] loss0.016-|Sample:20.41|
# [TEST]
# {'precision': array([0.01283788]), 'recall': array([0.02635391]), 'ndcg': array([0.02110211])}
# EPOCH[271/500] loss0.016-|Sample:20.13|
# EPOCH[272/500] loss0.016-|Sample:21.27|
# EPOCH[273/500] loss0.016-|Sample:21.43|
# EPOCH[274/500] loss0.016-|Sample:20.15|
# EPOCH[275/500] loss0.016-|Sample:21.19|
# EPOCH[276/500] loss0.016-|Sample:21.10|
# EPOCH[277/500] loss0.016-|Sample:19.84|
# EPOCH[278/500] loss0.016-|Sample:21.10|
# EPOCH[279/500] loss0.016-|Sample:19.72|
# EPOCH[280/500] loss0.016-|Sample:20.40|
# [TEST]
# {'precision': array([0.01317734]), 'recall': array([0.02708746]), 'ndcg': array([0.02159994])}
# EPOCH[281/500] loss0.016-|Sample:19.34|
# EPOCH[282/500] loss0.015-|Sample:19.99|
# EPOCH[283/500] loss0.016-|Sample:18.61|
# EPOCH[284/500] loss0.015-|Sample:19.98|
# EPOCH[285/500] loss0.015-|Sample:18.33|
# EPOCH[286/500] loss0.015-|Sample:20.07|
# EPOCH[287/500] loss0.015-|Sample:18.24|
# EPOCH[288/500] loss0.015-|Sample:20.03|
# EPOCH[289/500] loss0.015-|Sample:18.16|
# EPOCH[290/500] loss0.015-|Sample:19.82|
# [TEST]
# {'precision': array([0.01343154]), 'recall': array([0.02780225]), 'ndcg': array([0.02236345])}
# EPOCH[291/500] loss0.015-|Sample:19.77|
# EPOCH[292/500] loss0.015-|Sample:18.30|
# EPOCH[293/500] loss0.015-|Sample:19.77|
# EPOCH[294/500] loss0.015-|Sample:18.35|
# EPOCH[295/500] loss0.015-|Sample:19.47|
# EPOCH[296/500] loss0.015-|Sample:19.00|
# EPOCH[297/500] loss0.015-|Sample:21.37|
# EPOCH[298/500] loss0.015-|Sample:21.30|
# EPOCH[299/500] loss0.015-|Sample:18.66|
# EPOCH[300/500] loss0.015-|Sample:20.37|
# [TEST]
# {'precision': array([0.01352154]), 'recall': array([0.0281314]), 'ndcg': array([0.02256942])}
# EPOCH[301/500] loss0.015-|Sample:19.36|
# EPOCH[302/500] loss0.015-|Sample:18.16|
# EPOCH[303/500] loss0.015-|Sample:19.74|
# EPOCH[304/500] loss0.015-|Sample:18.03|
# EPOCH[305/500] loss0.015-|Sample:19.59|
# EPOCH[306/500] loss0.015-|Sample:17.97|
# EPOCH[307/500] loss0.015-|Sample:19.56|
# EPOCH[308/500] loss0.015-|Sample:17.94|
# EPOCH[309/500] loss0.014-|Sample:19.57|
# EPOCH[310/500] loss0.015-|Sample:18.52|
# [TEST]
# {'precision': array([0.01382152]), 'recall': array([0.02877015]), 'ndcg': array([0.02319647])}
# EPOCH[311/500] loss0.014-|Sample:18.01|
# EPOCH[312/500] loss0.015-|Sample:19.37|
# EPOCH[313/500] loss0.015-|Sample:17.99|
# EPOCH[314/500] loss0.014-|Sample:19.13|
# EPOCH[315/500] loss0.014-|Sample:18.27|
# EPOCH[316/500] loss0.014-|Sample:19.59|
# EPOCH[317/500] loss0.014-|Sample:17.99|
# EPOCH[318/500] loss0.014-|Sample:19.18|
# EPOCH[319/500] loss0.014-|Sample:18.67|
# EPOCH[320/500] loss0.014-|Sample:19.02|
# [TEST]
# {'precision': array([0.01402046]), 'recall': array([0.02918464]), 'ndcg': array([0.0235552])}
# EPOCH[321/500] loss0.014-|Sample:18.18|
# EPOCH[322/500] loss0.014-|Sample:18.67|
# EPOCH[323/500] loss0.014-|Sample:18.85|
# EPOCH[324/500] loss0.014-|Sample:17.94|
# EPOCH[325/500] loss0.014-|Sample:18.53|
# EPOCH[326/500] loss0.014-|Sample:18.38|
# EPOCH[327/500] loss0.014-|Sample:18.50|
# EPOCH[328/500] loss0.014-|Sample:18.04|
# EPOCH[329/500] loss0.014-|Sample:18.88|
# EPOCH[330/500] loss0.014-|Sample:18.09|
# [TEST]
# {'precision': array([0.01407099]), 'recall': array([0.02948617]), 'ndcg': array([0.02384994])}
# EPOCH[331/500] loss0.014-|Sample:17.99|
# EPOCH[332/500] loss0.014-|Sample:19.63|
# EPOCH[333/500] loss0.014-|Sample:18.07|
# EPOCH[334/500] loss0.014-|Sample:19.24|
# EPOCH[335/500] loss0.014-|Sample:17.86|
# EPOCH[336/500] loss0.014-|Sample:19.39|
# EPOCH[337/500] loss0.014-|Sample:18.42|
# EPOCH[338/500] loss0.014-|Sample:19.89|
# EPOCH[339/500] loss0.013-|Sample:18.11|
# EPOCH[340/500] loss0.014-|Sample:19.32|
# [TEST]
# {'precision': array([0.01431571]), 'recall': array([0.0299383]), 'ndcg': array([0.02430941])}
# EPOCH[341/500] loss0.014-|Sample:18.83|
# EPOCH[342/500] loss0.014-|Sample:18.08|
# EPOCH[343/500] loss0.014-|Sample:19.09|
# EPOCH[344/500] loss0.014-|Sample:17.61|
# EPOCH[345/500] loss0.013-|Sample:19.36|
# EPOCH[346/500] loss0.013-|Sample:17.77|
# EPOCH[347/500] loss0.013-|Sample:19.34|
# EPOCH[348/500] loss0.014-|Sample:18.23|
# EPOCH[349/500] loss0.014-|Sample:21.13|
# EPOCH[350/500] loss0.013-|Sample:21.07|
# [TEST]
# {'precision': array([0.01439466]), 'recall': array([0.03016611]), 'ndcg': array([0.02430087])}
# EPOCH[351/500] loss0.013-|Sample:19.96|
# EPOCH[352/500] loss0.013-|Sample:18.21|
# EPOCH[353/500] loss0.013-|Sample:20.11|
# EPOCH[354/500] loss0.013-|Sample:18.35|
# EPOCH[355/500] loss0.013-|Sample:20.05|
# EPOCH[356/500] loss0.013-|Sample:18.31|
# EPOCH[357/500] loss0.013-|Sample:19.92|
# EPOCH[358/500] loss0.013-|Sample:18.15|
# EPOCH[359/500] loss0.013-|Sample:19.79|
# EPOCH[360/500] loss0.013-|Sample:18.52|
# [TEST]
# {'precision': array([0.0148178]), 'recall': array([0.03108078]), 'ndcg': array([0.025238])}
# EPOCH[361/500] loss0.013-|Sample:18.09|
# EPOCH[362/500] loss0.013-|Sample:19.78|
# EPOCH[363/500] loss0.013-|Sample:17.99|
# EPOCH[364/500] loss0.013-|Sample:19.60|
# EPOCH[365/500] loss0.013-|Sample:17.89|
# EPOCH[366/500] loss0.013-|Sample:19.47|
# EPOCH[367/500] loss0.013-|Sample:18.11|
# EPOCH[368/500] loss0.013-|Sample:19.10|
# EPOCH[369/500] loss0.013-|Sample:18.21|
# EPOCH[370/500] loss0.013-|Sample:19.33|
# [TEST]
# {'precision': array([0.01496148]), 'recall': array([0.03142312]), 'ndcg': array([0.02554902])}
# EPOCH[371/500] loss0.013-|Sample:18.62|
# EPOCH[372/500] loss0.013-|Sample:18.21|
# EPOCH[373/500] loss0.013-|Sample:18.64|
# EPOCH[374/500] loss0.013-|Sample:18.19|
# EPOCH[375/500] loss0.013-|Sample:19.04|
# EPOCH[376/500] loss0.013-|Sample:18.21|
# EPOCH[377/500] loss0.013-|Sample:19.42|
# EPOCH[378/500] loss0.013-|Sample:18.09|
# EPOCH[379/500] loss0.013-|Sample:19.14|
# EPOCH[380/500] loss0.013-|Sample:18.07|
# [TEST]
# {'precision': array([0.01510357]), 'recall': array([0.03183233]), 'ndcg': array([0.02591837])}
# EPOCH[381/500] loss0.013-|Sample:18.27|
# EPOCH[382/500] loss0.013-|Sample:19.26|
# EPOCH[383/500] loss0.012-|Sample:18.69|
# EPOCH[384/500] loss0.013-|Sample:18.55|
# EPOCH[385/500] loss0.013-|Sample:18.07|
# EPOCH[386/500] loss0.012-|Sample:19.08|
# EPOCH[387/500] loss0.013-|Sample:18.17|
# EPOCH[388/500] loss0.012-|Sample:18.91|
# EPOCH[389/500] loss0.012-|Sample:18.23|
# EPOCH[390/500] loss0.013-|Sample:19.52|
# [TEST]
# {'precision': array([0.01527883]), 'recall': array([0.03235562]), 'ndcg': array([0.0262453])}
# EPOCH[391/500] loss0.013-|Sample:18.36|
# EPOCH[392/500] loss0.012-|Sample:18.79|
# EPOCH[393/500] loss0.012-|Sample:18.35|
# EPOCH[394/500] loss0.012-|Sample:17.99|
# EPOCH[395/500] loss0.012-|Sample:19.00|
# EPOCH[396/500] loss0.012-|Sample:18.80|
# EPOCH[397/500] loss0.012-|Sample:18.51|
# EPOCH[398/500] loss0.012-|Sample:18.18|
# EPOCH[399/500] loss0.012-|Sample:19.48|
# EPOCH[400/500] loss0.012-|Sample:18.08|
# [TEST]
# {'precision': array([0.01529778]), 'recall': array([0.03231707]), 'ndcg': array([0.02648558])}
# EPOCH[401/500] loss0.012-|Sample:17.79|
# EPOCH[402/500] loss0.012-|Sample:19.15|
# EPOCH[403/500] loss0.012-|Sample:18.14|
# EPOCH[404/500] loss0.012-|Sample:19.04|
# EPOCH[405/500] loss0.012-|Sample:18.09|
# EPOCH[406/500] loss0.012-|Sample:19.31|
# EPOCH[407/500] loss0.012-|Sample:18.20|
# EPOCH[408/500] loss0.012-|Sample:19.55|
# EPOCH[409/500] loss0.012-|Sample:18.22|
# EPOCH[410/500] loss0.012-|Sample:19.37|
# [TEST]
# {'precision': array([0.01538146]), 'recall': array([0.03266964]), 'ndcg': array([0.0266206])}
# EPOCH[411/500] loss0.012-|Sample:18.90|
# EPOCH[412/500] loss0.012-|Sample:19.67|
# EPOCH[413/500] loss0.012-|Sample:18.32|
# EPOCH[414/500] loss0.012-|Sample:19.64|
# EPOCH[415/500] loss0.012-|Sample:18.01|
# EPOCH[416/500] loss0.012-|Sample:19.36|
# EPOCH[417/500] loss0.012-|Sample:18.44|
# EPOCH[418/500] loss0.012-|Sample:19.81|
# EPOCH[419/500] loss0.012-|Sample:18.00|
# EPOCH[420/500] loss0.012-|Sample:19.65|
# [TEST]
# {'precision': array([0.01555671]), 'recall': array([0.03310182]), 'ndcg': array([0.02681257])}
# EPOCH[421/500] loss0.012-|Sample:19.80|
# EPOCH[422/500] loss0.012-|Sample:18.13|
# EPOCH[423/500] loss0.012-|Sample:19.68|
# EPOCH[424/500] loss0.012-|Sample:18.12|
# EPOCH[425/500] loss0.012-|Sample:19.56|
# EPOCH[426/500] loss0.012-|Sample:18.17|
# EPOCH[427/500] loss0.012-|Sample:19.54|
# EPOCH[428/500] loss0.012-|Sample:18.22|
# EPOCH[429/500] loss0.012-|Sample:19.57|
# EPOCH[430/500] loss0.012-|Sample:17.96|
# [TEST]
# {'precision': array([0.01576197]), 'recall': array([0.0335835]), 'ndcg': array([0.02743099])}
# EPOCH[431/500] loss0.012-|Sample:18.12|
# EPOCH[432/500] loss0.012-|Sample:19.85|
# EPOCH[433/500] loss0.012-|Sample:18.56|
# EPOCH[434/500] loss0.012-|Sample:19.31|
# EPOCH[435/500] loss0.012-|Sample:18.36|
# EPOCH[436/500] loss0.012-|Sample:19.28|
# EPOCH[437/500] loss0.012-|Sample:18.03|
# EPOCH[438/500] loss0.012-|Sample:19.86|
# EPOCH[439/500] loss0.012-|Sample:18.15|
# EPOCH[440/500] loss0.012-|Sample:19.27|
# [TEST]
# {'precision': array([0.0158046]), 'recall': array([0.03385194]), 'ndcg': array([0.02747895])}
# EPOCH[441/500] loss0.012-|Sample:18.93|
# EPOCH[442/500] loss0.012-|Sample:17.99|
# EPOCH[443/500] loss0.012-|Sample:19.25|
# EPOCH[444/500] loss0.011-|Sample:18.50|
# EPOCH[445/500] loss0.011-|Sample:19.00|
# EPOCH[446/500] loss0.012-|Sample:18.21|
# EPOCH[447/500] loss0.011-|Sample:19.19|
# EPOCH[448/500] loss0.012-|Sample:18.02|
# EPOCH[449/500] loss0.012-|Sample:19.69|
# EPOCH[450/500] loss0.012-|Sample:17.79|
# [TEST]
# {'precision': array([0.01583933]), 'recall': array([0.03384325]), 'ndcg': array([0.02759182])}
# EPOCH[451/500] loss0.011-|Sample:18.43|
# EPOCH[452/500] loss0.011-|Sample:18.69|
# EPOCH[453/500] loss0.011-|Sample:17.84|
# EPOCH[454/500] loss0.011-|Sample:19.63|
# EPOCH[455/500] loss0.011-|Sample:17.78|
# EPOCH[456/500] loss0.011-|Sample:19.69|
# EPOCH[457/500] loss0.011-|Sample:17.92|
# EPOCH[458/500] loss0.011-|Sample:19.56|
# EPOCH[459/500] loss0.011-|Sample:18.08|
# EPOCH[460/500] loss0.011-|Sample:19.23|
# [TEST]
# {'precision': array([0.01611879]), 'recall': array([0.0345755]), 'ndcg': array([0.02801568])}
# EPOCH[461/500] loss0.011-|Sample:18.79|
# EPOCH[462/500] loss0.011-|Sample:17.96|
# EPOCH[463/500] loss0.011-|Sample:19.22|
# EPOCH[464/500] loss0.011-|Sample:17.95|
# EPOCH[465/500] loss0.011-|Sample:18.98|
# EPOCH[466/500] loss0.011-|Sample:18.43|
# EPOCH[467/500] loss0.011-|Sample:19.32|
# EPOCH[468/500] loss0.011-|Sample:18.60|
# EPOCH[469/500] loss0.011-|Sample:19.02|
# EPOCH[470/500] loss0.011-|Sample:19.75|
# [TEST]
# {'precision': array([0.0163651]), 'recall': array([0.03504573]), 'ndcg': array([0.02852434])}
# EPOCH[471/500] loss0.011-|Sample:20.05|
# EPOCH[472/500] loss0.011-|Sample:18.78|
# EPOCH[473/500] loss0.011-|Sample:19.98|
# EPOCH[474/500] loss0.011-|Sample:18.45|
# EPOCH[475/500] loss0.011-|Sample:20.33|
# EPOCH[476/500] loss0.011-|Sample:18.73|
# EPOCH[477/500] loss0.011-|Sample:19.80|
# EPOCH[478/500] loss0.011-|Sample:18.52|
# EPOCH[479/500] loss0.011-|Sample:20.37|
# EPOCH[480/500] loss0.011-|Sample:18.39|
# [TEST]
# {'precision': array([0.01633194]), 'recall': array([0.03517884]), 'ndcg': array([0.02842776])}
# EPOCH[481/500] loss0.011-|Sample:18.22|
# EPOCH[482/500] loss0.011-|Sample:19.36|
# EPOCH[483/500] loss0.011-|Sample:18.37|
# EPOCH[484/500] loss0.011-|Sample:19.23|
# EPOCH[485/500] loss0.011-|Sample:18.67|
# EPOCH[486/500] loss0.011-|Sample:19.43|
# EPOCH[487/500] loss0.011-|Sample:18.83|
# EPOCH[488/500] loss0.011-|Sample:18.81|
# EPOCH[489/500] loss0.011-|Sample:19.20|
# EPOCH[490/500] loss0.011-|Sample:18.65|
# [TEST]
# {'precision': array([0.01654194]), 'recall': array([0.03562376]), 'ndcg': array([0.0288361])}
# EPOCH[491/500] loss0.011-|Sample:18.38|
# EPOCH[492/500] loss0.011-|Sample:20.30|
# EPOCH[493/500] loss0.011-|Sample:18.57|
# EPOCH[494/500] loss0.011-|Sample:19.98|
# EPOCH[495/500] loss0.011-|Sample:18.49|
# EPOCH[496/500] loss0.011-|Sample:20.03|
# EPOCH[497/500] loss0.011-|Sample:18.45|
# EPOCH[498/500] loss0.011-|Sample:20.11|
# EPOCH[499/500] loss0.011-|Sample:18.46|
# EPOCH[500/500] loss0.011-|Sample:19.86|

# %%
# Save user and item embeddings to separate files

#np.save(user_emb_file, Recmodel.embedding_user.weight.data.cpu().numpy())
#np.save(item_emb_file, Recmodel.embedding_item.weight.data.cpu().numpy())

#user_emb_file = "user_emb.npy"
#item_emb_file = "item_emb.npy"

#world.config['user_emb'] = np.load(user_emb_file)
#world.config['item_emb'] = np.load(item_emb_file)

# %%
import numpy as np
import os
# Create a folder to store the embeddings
#embedding_folder = "embeddings"
#os.makedirs(embedding_folder, exist_ok=True)

# Get the user and item embeddings from the trained model
#user_embeddings = Recmodel.embedding_user.weight.data.cpu().numpy()
#item_embeddings = Recmodel.embedding_item.weight.data.cpu().numpy()

# Save the embeddings to files
#user_emb_file = os.path.join(embedding_folder, "user_embeddings.npy")
#item_emb_file = os.path.join(embedding_folder, "item_embeddings.npy")
#np.save(user_emb_file, user_embeddings)
#np.save(item_emb_file, item_embeddings)
